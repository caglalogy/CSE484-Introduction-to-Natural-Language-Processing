# %% [markdown]
# # Cleaning file
#
# wiki_00 file includes some lines starting with <doc, </doc> and many newlines. To get rid of them, file is rewritten.

# %%
import re

# %%
with open("wiki_00", "r") as f:
    with open("wiki.txt", "w") as new_f:
        # Read each line from the original file
        for line in f:
            # Check if the line starts with "</doc>"
            if line.startswith("</doc>") or line.startswith("<doc") or line.startswith("\n"):
                # Skip the line
                continue
            # If the line does not start with "</doc>", write it to the new file
            new_f.write(line)
f.close()
new_f.close()

# %% [markdown]
# Now, reopen the edited file, to preprocess it before creating n-grams.

# %%
f = open("wiki.txt", "r")
wiki_text = f.read()
f.close()

# %%
type(wiki_text)
# Out:
# str

# %%
wiki_text[:35]
# Out:
# 'Cengiz Han\nCengiz Han ("Cenghis Kha'

# %% [markdown]
# wiki_text includes all the file in one string. To seperate it into words, split it from wspaces and store into a list.

# %%
content_list = re.split('(\W)', wiki_text)

# %%
len(content_list)
# Out:
# 128700673

# %% [markdown]
# content_list sample:

# %%
content_list[150:500]
# Out:
# ['daki',
#  ' ',
#  'tüm',
#  ' ',
#  'göçebe',
#  ' ',
#  'bozkır',
#  ' ',
#  'kavimlerini',
#  ' ',
#  'birleştirerek',
#  ' ',
#  'bir',
#  ' ',
#  'ulus',
#  ' ',
#  'haline',
#  ' ',
#  'getirdi',
#  ' ',
#  've',
#  ' ',
#  'o',
#  ' ',
#  'ulusu',
#  ' ',
#  '',
#  '"',
#  'Moğol',
#  '"',
#  '',
#  ' ',
#  'siyasi',
#  ' ',
#  'kimliği',
#  ' ',
#  'çatısı',
#  ' ',
#  'altında',
#  ' ',
#  'topladı',
#  '.',
#  '',
#  ' ',
#  'Dünya',
#  ' ',
#  'tarihinin',
#  ' ',
#  'en',
#  ' ',
#  'büyük',
#  ' ',
#  'askeri',
#  ' ',
#  'dehalarından',
#  ' ',
#  'biri',
#  ' ',
#  'olarak',
#  ' ',
#  'kabul',
#  ' ',
#  'edilen',
#  ' ',
#  'Cengiz',
#  ' ',
#  'Han',
#  ',',
#  '',
#  ' ',
#  'hükümdarlığı',
#  ' ',
#  'döneminde',
#  ' ',
#  '1206',
#  '-',
#  '1227',
#  ' ',
#  'arasında',
#  ' ',
#  'Kuzey',
#  ' ',
#  'Çin',
#  "'",
#  'deki',
#  ' ',
#  'Batı',
#  ' ',
#  'Xia',
#  ' ',
#  've',
#  ' ',
#  'Jin',
#  ' ',
#  'Hanedanı',
#  ',',
#  '',
#  ' ',
#  'Türkistan',
#  "'",
#  'daki',
#  ' ',
#  'Kara',
#  ' ',
#  'Hıtay',
#  ',',
#  '',
#  ' ',
#  'Maveraünnehir',
#  ',',
#  '',
#  ' ',
#  'Harezm',
#  ',',
#  '',
#  ' ',
#  'Horasan',
#  ' ',
#  've',
#  ' ',
#  'İran',
#  "'",
#  'daki',
#  ' ',
#  'Harzemşahlar',
#  ' ',
#  'ile',
#  ' ',
#  'Kafkasya',
#  "'",
#  'da',
#  ' ',
#  'Gürcüler',
#  ',',
#  '',
#  ' ',
#  'Deşt',
#  '-',
#  'i',
#  ' ',
#  'Kıpçak',
#  "'",
#  'taki',
#  ' ',
#  'Rus',
#  ' ',
#  'Knezlikleri',
#  ' ',
#  've',
#  ' ',
#  'Kıpçaklar',
#  ' ',
#  'ile',
#  ' ',
#  'İdil',
#  ' ',
#  'Bulgarları',
#  ' ',
#  'üzerine',
#  ' ',
#  'gerçekleştirilen',
#  ' ',
#  'seferler',
#  ' ',
#  'sonucunda',
#  ' ',
#  'Pasifik',
#  ' ',
#  'Okyanusu',
#  "'",
#  'ndan',
#  ' ',
#  'Hazar',
#  ' ',
#  'Denizi',
#  '’',
#  'ne',
#  ' ',
#  've',
#  ' ',
#  'Karadeniz',
#  "'",
#  'in',
#  ' ',
#  'kuzeyine',
#  ' ',
#  'kadar',
#  ' ',
#  'uzanan',
#  ' ',
#  'bir',
#  ' ',
#  'imparatorluk',
#  ' ',
#  'kurdu',
#  '.',
#  '',
#  '\n',
#  'Bozkır',
#  ' ',
#  'geleneğinden',
#  ' ',
#  'gelen',
#  ' ',
#  'onlu',
#  ' ',
#  'teşkilatı',
#  ' ',
#  'kullanarak',
#  ' ',
#  'Meritokratik',
#  ' ',
#  '',
#  '(',
#  'liyâkata',
#  ' ',
#  'bağlı',
#  ')',
#  '',
#  ' ',
#  'bir',
#  ' ',
#  'ordu',
#  ' ',
#  'meydana',
#  ' ',
#  'getiren',
#  ' ',
#  'Cengiz',
#  ' ',
#  'Han',
#  '’',
#  'ın',
#  ' ',
#  'büyük',
#  ' ',
#  'bir',
#  ' ',
#  'asker',
#  ' ',
#  'olarak',
#  ' ',
#  'ün',
#  ' ',
#  'kazanmasının',
#  ' ',
#  'temelinde',
#  ',',
#  '',
#  ' ',
#  'kurduğu',
#  ' ',
#  'posta',
#  ' ',
#  'teşkilatı',
#  ' ',
#  've',
#  ' ',
#  'casus',
#  ' ',
#  'ağı',
#  ' ',
#  'ile',
#  ' ',
#  'istihbarat',
#  ' ',
#  'sanatına',
#  ' ',
#  'verdiği',
#  ' ',
#  'büyük',
#  ' ',
#  'değer',
#  ' ',
#  'önemli',
#  ' ',
#  'bir',
#  ' ',
#  'yer',
#  ' ',
#  'tutar',
#  '.',
#  '',
#  ' ',
#  'Seferleri',
#  ' ',
#  'sonucunda',
#  ',',
#  '',
#  ' ',
#  'pek',
#  ' ',
#  'çok',
#  ' ',
#  'şehir',
#  ' ',
#  'tahrip',
#  ' ',
#  'olmuş',
#  ' ',
#  've',
#  ' ',
#  'milyonlarca',
#  ' ',
#  'insan',
#  ' ',
#  'da',
#  ' ',
#  'katledilmişti',
#  ' ',
#  'ancak',
#  ' ',
#  '',
#  '"',
#  'Cengiz',
#  ' ',
#  'Han',
#  ' ',
#  'Yasası',
#  '"',
#  '',
#  ' ',
#  'adı',
#  ' ',
#  'ile',
#  ' ',
#  'metinleştirilen',
#  ' ',
#  'kurallar',
#  ' ',
#  'ile',
#  ' ',
#  'işkenceyi',
#  ' ',
#  'yasaklayıp',
#  ',',
#  '',
#  ' ',
#  'zanaatkarlar',
#  ',',
#  '',
#  ' ',
#  'doktorlar',
#  ',',
#  '',
#  ' ',
#  'belli',
#  ' ',
#  'bilgi',
#  ' ']

# %% [markdown]
# To not lose whitespaces, I will add whitespace after each word.

# %% [markdown]
# # Preprocessing text
# 1. Convert all the letters to small case letters first.
# 2. convert all Turkish characters to English ones. For example, ş -> s and ğ -> g
# 3. Remove punctuations
#
# 4. just newlines, whitespaces and lower-case characters

# %%
# analysing content_list size
len(content_list)
# Out:
# 128700673

# %%
# to decrease execution time, i will use the first quarter part of it. 
test_list = content_list[1000000:1050000]

# %%
print(test_list)
# Out:
# ['', ' ', 'bir', ' ', 'gün', ' ', 'eder', ' ', 've', ' ', 'yıla', ' ', 'eklenir', '.', '', ' ', 'Böylece', ' ', 'bir', ' ', 'yıl', ',', '', ' ', '4', ' ', 'yılda', ' ', 'bir', ' ', '366', ' ', 'güne', ' ', 'çıkar', '.', '', ' ', 'Ne', ' ', 'var', ' ', 'ki', ' ', '366', ' ', 'sayısı', ' ', '12', '’', 'ye', ' ', 'tam', ' ', 'olarak', ' ', 'bölünmediğinden', ' ', 'bazı', ' ', 'ayların', ' ', '30', ' ', 'bazı', ' ', 'ayların', ' ', 'da', ' ', '31', ' ', 'çekmesi', ' ', 'uygun', ' ', 'görülür', '.', '', ' ', 'Julyen', ' ', 'takviminde', ' ', 'yılbaşı', ',', '', ' ', 'mart', ' ', 'ayındadır', ' ', 've', ' ', 'buna', ' ', 'göre', ' ', 'şubat', ',', '', ' ', 'yılın', ' ', 'en', ' ', 'son', ' ', 'ayıdır', '.', '', ' ', '', '“', 'July', '”', '', ' ', 'olarak', ' ', 'bilinen', ' ', 'temmuz', ' ', 'ayı', ',', '', ' ', 'Julius', ' ', 'Caesar', '’', 'ın', ' ', 'adını', ' ', 'taşır', ' ', 've', ' ', '31', ' ', 'gün', ' ', 'sürer', '.', '', '\n', 'Caesar', '’', 'dan', ' ', 'sonra', ' ', 'yaşayan', ' ', 'bir', ' ', 'başka', ' ', 'Roma', ' ', 'İmparatoru', ' ', 'Augustus', ' ', 'da', ' ', 'kendi', ' ', 'adını', ' ', 'bir', ' ', 'aya', ' ', 'verir', '.', '', ' ', 'Ne', ' ', 'var', ' ', 'ki', ' ', 'Ağustos', ' ', '', '(', 'Augustus', '’', 'un', ' ', 'adından', ')', '', ' ', 'ayının', ' ', '30', ',', '', ' ', 'Caesar', '’', 'ın', ' ', 'adını', ' ', 'taşıyan', ' ', 'Temmuz', ' ', 'ayının', ' ', '31', ' ', 'çekmesini', ' ', 'haşmetine', ' ', 'yakıştıramayan', ' ', 'İmparator', ' ', 'Augustus', ',', '', ' ', 'kendi', ' ', 'adıyla', ' ', 'anılan', ' ', 'ayın', ' ', 'da', ' ', '31', ' ', 'gün', ' ', 'sürmesini', ' ', 'emreder', '.', '', ' ', 'Bunun', ' ', 'üzerine', ' ', 'astronomlar', ',', '', ' ', 'yılın', ' ', 'son', ' ', 'ayı', ' ', 'olan', ' ', 'şubattan', ' ', 'bir', ' ', 'günü', ' ', 'alıp', ',', '', ' ', 'ağustos', ' ', 'ayına', ' ', 'ekler', '.', '', ' ', 'Böylece', ' ', '30', '-', '29', ' ', 'gün', ' ', 'döngüsü', ' ', 'yaşayan', ' ', 'şubat', ' ', 'ayı', ' ', '29', '-', '28', ' ', 'gün', ' ', 'olarak', ' ', 'belirlenir', '.', '', '\n', 'Şubat', ',', '', ' ', 'yıl', ' ', 'Mart', ' ', 'ile', ' ', 'başladığı', ' ', 'için', ' ', 'Roma', ' ', 'takviminin', ' ', 'son', ' ', 'ayı', ' ', 'idi', '.', '', ' ', 'Belirli', ' ', 'zaman', ' ', 'aralıklarında', ' ', 'Romalı', ' ', 'rahipler', ',', '', ' ', 'yılı', ' ', 'mevsimlerle', ' ', 'hizalayabilmek', ' ', 'için', ',', '', ' ', 'Şubat', "'", 'tan', ' ', 'sonra', ' ', 'araya', ' ', 'bir', ' ', 'eklenti', ' ', 'ay', ' ', '', '(', 'Mercedonius', ')', '', ' ', 'yerleştiriyorlardı', '.', '', '\n', 'Ocak', '\n', 'Ocak', ' ', 'ayı', ' ', 'Gregoryen', ' ', 've', ' ', 'Jülyen', ' ', 'takvimlerinde', ' ', 'yılın', ' ', 'ilk', ' ', 'ayıdır', '.', '', ' ', 'Sözcüğün', ',', '', ' ', 'odcak', ' ', '', '»', '', '>', '', ' ', '', '"', 'ocak', '"', '', ' ', 'olduğu', ' ', 'savlanırken', ',', '', ' ', 'öte', ' ', 'yandan', ' ', 'Eski', ' ', 'Türkçedeki', ' ', '', '"', 'oc', '-', 'mak', ',', '', ' ', 'uc', '-', 'mak', '"', '', ' ', '', '"', 'ateş', ' ', 'tutuşturmak', '"', '', ' ', 'kökünden', ' ', 'de', ' ', 'olabilir', '.', '', ' ', 'Ocak', ',', '', ' ', 'ateş', ' ', 'yakılan', ' ', 'yer', ',', '', ' ', 'ev', ',', '', ' ', 'yuva', ' ', 'sözcükleriyle', ' ', 'bağlantılı', ' ', 'olup', ' ', 'ocakların', ' ', 'yakıldığı', ',', '', ' ', 'günlerin', ' ', 'dışarıda', ' ', 'çalışarak', ',', '', ' ', 'avlanarak', ' ', 'değil', ' ', 'de', ',', '', ' ', 'ocaklarda', ' ', '', '(', 'evlerde', ')', '', ' ', 'geçirildiği', ' ', 'soğuk', ' ', 'ay', ',', '', ' ', 'anlamını', ' ', 'taşımaktadır', '.', '', ' ', 'Ocak', ' ', 'adı', ' ', 'ayrıca', ' ', 'üç', ' ', 'uzun', ' ', 'çubukla', ' ', 'ateş', ' ', 'üstünde', ' ', 'duran', ' ', 'pişirme', ' ', 'kabının', ' ', 'tutulmasına', ' ', 'yarayan', ' ', 'düzeneğin', ',', '', ' ', 'üçok', "'", 'un', ' ', 'adının', ' ', 'evrilmesi', ' ', 'sonucunda', ' ', 'da', ' ', 'bugünkü', ' ', 'formuna', ' ', 'kavuşmuş', ' ', 'olabilir', '.', '', '\n', 'Ocak', ' ', 'ayı', ' ', 'batı', ' ', 'dillerinde',  ...

# %%
content_list = content_list[:1000000]

# %%
print(len(test_list), len(content_list))
# Out:
# 50000 1000000

# %%
import string
content_list = list(map(lambda x: x.lower(), content_list))
test_list = list(map(lambda x: x.lower(), test_list))

# %% [markdown]
# All the words are in lowercase form now. (1 - done)

# %%
# Create a translation table
table = str.maketrans("çğıöşü", "cgiosu")
content_list = list(map(lambda x:x.translate(table), content_list))
test_list = list(map(lambda x:x.translate(table), test_list))
content_list[:15]
# Out:
# ['cengiz',
#  ' ',
#  'han',
#  '\n',
#  'cengiz',
#  ' ',
#  'han',
#  ' ',
#  '',
#  '(',
#  '',
#  '"',
#  'cenghis',
#  ' ',
#  'khan']

# %% [markdown]
# All Turkish characters are converted to English ones (2 - done)

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree


#storing the puntuation free text
content_list = list(map(lambda x:remove_punctuation(x), content_list))
test_list = list(map(lambda x:remove_punctuation(x), test_list))

content_list[:30]
# Out:
# ['cengiz',
#  ' ',
#  'han',
#  '\n',
#  'cengiz',
#  ' ',
#  'han',
#  ' ',
#  '',
#  '',
#  '',
#  '',
#  'cenghis',
#  ' ',
#  'khan',
#  '',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  'cinggis',
#  ' ',
#  'haan',
#  '',
#  '',
#  ' ',
#  'ya',
#  ' ']

# %% [markdown]
# All the punctuations are removed.

# %%
# removing empty elements
content_list = [value for value in content_list if value != '']
test_list = [value for value in test_list if value != '']

# %% [markdown]
# # Seperating each word into syllables

# %% [markdown]
# ## For this purpose, the library below is used.

# %%
! python -m pip install git+https://github.com/ftkurt/python-syllable.git@master
# Out:
# Collecting git+https://github.com/ftkurt/python-syllable.git@master
#   Cloning https://github.com/ftkurt/python-syllable.git (to revision master) to /private/var/folders/hz/fspw4bl94hx704xyxs5cdkdc0000gn/T/pip-req-build-b_3c86gp
#   Running command git clone --filter=blob:none --quiet https://github.com/ftkurt/python-syllable.git /private/var/folders/hz/fspw4bl94hx704xyxs5cdkdc0000gn/T/pip-req-build-b_3c86gp
#   Resolved https://github.com/ftkurt/python-syllable.git to commit e0a4d99e55a2e27c87b2a5cec9532dcb14e3817d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from syllable==0.0.1) (3.7)
# Requirement already satisfied: pytest in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from syllable==0.0.1) (7.1.2)
# Requirement already satisfied: hypothesis in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from syllable==0.0.1) (6.61.0)
# Requirement already satisfied: mypy in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from syllable==0.0.1) (0.991)
# Requirement already satisfied: unidecode in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from syllable==0.0.1) (1.2.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from hypothesis->syllable==0.0.1) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from hypothesis->syllable==0.0.1) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from hypothesis->syllable==0.0.1) (1.0.4)
# Requirement already satisfied: tomli>=1.1.0 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from mypy->syllable==0.0.1) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from mypy->syllable==0.0.1) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.10 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from mypy->syllable==0.0.1) (4.3.0)
# Requirement already satisfied: tqdm in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from nltk->syllable==0.0.1) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from nltk->syllable==0.0.1) (2022.7.9)
# Requirement already satisfied: click in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from nltk->syllable==0.0.1) (8.0.4)
# Requirement already satisfied: joblib in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from nltk->syllable==0.0.1) (1.1.0)
# Requirement already satisfied: iniconfig in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from pytest->syllable==0.0.1) (1.1.1)
# Requirement already satisfied: packaging in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from pytest->syllable==0.0.1) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from pytest->syllable==0.0.1) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from pytest->syllable==0.0.1) (1.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/cagla/opt/anaconda3/lib/python3.9/site-packages (from packaging->pytest->syllable==0.0.1) (3.0.9)

# %%
from syllable import Encoder

# %%
encoder = Encoder(lang="tr", limitby="vocabulary", limit=3000)  

syllables = []
i = 0
for item in content_list:
    if(item == ' '):
        syllables.append(item)
    elif(item == '\n'):
        syllables.append(item)
    else:
        a = encoder.tokenize(item)
        list_syllables_of_word = a.split(" ")
        for syl in list_syllables_of_word:
            syllables.append(syl)
    
    
syllables_test = []
i = 0
for item in test_list:
    if(item == ' '):
        syllables_test.append(item)
    elif(item == '\n'):
        syllables_test.append(item)
    else:
        a = encoder.tokenize(item)
        list_syllables_of_word_t = a.split(" ")
        for syl in list_syllables_of_word_t:
            syllables_test.append(syl)

# %% [markdown]
# ## Syllables are stored in two different lists, `syllables` and `syllables_test`.

# %%
print(syllables[:10])
print(syllables_test[:10])
# Out:
# ['cen', 'giz', ' ', 'han', '\n', 'cen', 'giz', ' ', 'han', ' ']
# [' ', 'bir', ' ', 'gun', ' ', 'e', 'der', ' ', 've', ' ']

# %% [markdown]
# # Creating n-grams

# %%
import pandas as pd
# natural language processing: n-gram ranking
import re
import unicodedata
import nltk

# %% [markdown]
# ## Creating 1-gram

# %%
# to see what i get, let' see top 50
(pd.Series(nltk.ngrams(syllables, 1)).value_counts())[:50]
# Out:
# ( ,)      395313
# (,)        30848
# (la,)      30141
# (le,)      25740
# (ri,)      25023
# (si,)      22506
# (da,)      22010
# (de,)      21279
# (i,)       19377
# (li,)      18748
# (ya,)      17507
# (a,)       16754
# (o,)       16020
# (ve,)      15644
# (di,)      15578
# (ma,)      14490
# (ni,)      14329
# (ta,)      13627
# (ra,)      13419
# (gi,)      13115
# (ki,)      12464
# (ti,)      12461
# (sa,)      10547
# (bir,)     10409
# (te,)      10293
# (bu,)      10227
# (ka,)      10184
# (nin,)     10056
# (ne,)       9647
# (\n,)       8991
# (bi,)       8706
# (na,)       8556
# (me,)       8542
# (re,)       8523
# (ge,)       8247
# (lar,)      8218
# (e,)        8128
# (rin,)      8084
# (dir,)      7938
# (ler,)      7772
# (lan,)      7434
# (ye,)       7233
# (ci,)       7191
# (ce,)       7021
# (se,)       6791
# (mi,)       6745
# (mis,)      6743
# (du,)       6674
# (yi,)       6643
# (gu,)       6273
# dtype: int64

# %%
onegram = pd.Series(nltk.ngrams(syllables, 1)).value_counts()

# %%
print(onegram.to_dict())
# Out:
# {(' ',): 395313, ('',): 30848, ('la',): 30141, ('le',): 25740, ('ri',): 25023, ('si',): 22506, ('da',): 22010, ('de',): 21279, ('i',): 19377, ('li',): 18748, ('ya',): 17507, ('a',): 16754, ('o',): 16020, ('ve',): 15644, ('di',): 15578, ('ma',): 14490, ('ni',): 14329, ('ta',): 13627, ('ra',): 13419, ('gi',): 13115, ('ki',): 12464, ('ti',): 12461, ('sa',): 10547, ('bir',): 10409, ('te',): 10293, ('bu',): 10227, ('ka',): 10184, ('nin',): 10056, ('ne',): 9647, ('\n',): 8991, ('bi',): 8706, ('na',): 8556, ('me',): 8542, ('re',): 8523, ('ge',): 8247, ('lar',): 8218, ('e',): 8128, ('rin',): 8084, ('dir',): 7938, ('ler',): 7772, ('lan',): 7434, ('ye',): 7233, ('ci',): 7191, ('ce',): 7021, ('se',): 6791, ('mi',): 6745, ('mis',): 6743, ('du',): 6674, ('yi',): 6643, ('
# %% [markdown]
# ## Creating 3-gram

# %%
threegram = pd.Series(nltk.ngrams(syllables, 3)).value_counts()

# %%
print(threegram)
# Out:
# ( , ,  )         13741
# ( , ve,  )       12922
# ( , bir,  )       8284
# ( , bu,  )        4617
# ( , o, la)        3999
#                  ...
# (cu,  , fi)          1
# (lo, la, ra)         1
# (tom,  , fik)        1
# (ce, rir, di)        1
# (tar,  , ar)         1
# Length: 166928, dtype: int64

# %% [markdown]
# # Smoothing ( good-turing smoothing)

# %%
dict_1gram = onegram.to_dict()

# %%
dict_2gram = twogram.to_dict()

# %%
dict_3gram = threegram.to_dict()

# %% [markdown]
# Converting 1-gram dict keys to string from tuple.

# %%
new_dict = {}

for key in dict_1gram:
    key_s = ''
    for item in key:
        key_s = key_s + item
    new_dict[key_s] = dict_1gram[key]

# print(new_dict)
dict_1gram = new_dict

# %%
def occurrence_counter(my_dict, value):
    count = 0
    # Iterate over the dictionary's values
    for n in my_dict.values():
      # If the current value is equal to the target value, increment the counter
      if n == value:
        count += 1
    return count

# %% [markdown]
# # Good-Turing Smoothing

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# On count numbers, there are many holes. While making good-turing smoothing, this holes affects the probabilities, whats worse is making them 0. To fix that, I will use lineer-regression.

# %%
from collections import Counter

def good_turing_smoothing(words):
    
    frequencies = {}
    for word, count in words.items():
        frequencies[word] = occurrence_counter(words, count)

    N = list(frequencies.values())
    n = [N.count(x) for x in N]

    # Sort the observed frequencies and counts in descending order
    N, n = zip(*sorted(zip(N, n), reverse=False))

    # Convert the observed frequencies and counts to numpy arrays
    N = np.array(N).reshape(-1, 1)
    n = np.array(n).reshape(-1, 1)


    # Create a linear regression model
    model = LinearRegression()

    # Fit the model to the data
    model.fit(N, n)

    # Predict the unobserved frequencies
    n_hat = model.predict(np.array([0]).reshape(-1, 1))
    
    # Initialize a dictionary to store the smoothed probabilities
    smoothed_probs = {}

  # Iterate over the observed frequencies and counts
    for i, (N_i, n_i) in enumerate(zip(N, n)):
        # If the observed frequency is zero, use the predicted unobserved frequency
        if N_i == 0:
            N_hat_i = n_hat
        # If the observed frequency is greater than zero, use the Good-Turing formula to estimate the probability
        else:
            if i == len(n)-1:
                x = 1
            else: 
                N_hat_i = (N_i + 1) * n[i+1] / n_i
        # Calculate the smoothed probability
        prob = N_i / sum(N)
        # Store the smoothed probability in the dictionary
        for word, count in frequencies.items():
            if count == N_i:
                smoothed_probs[word] = prob

      # Return the smoothed probabilities
    
    
    reversed_values = list(reversed(smoothed_probs.values()))

    i = 0
    for word in smoothed_probs.keys():
        smoothed_probs[word] = reversed_values[i]
        i+=1

    return smoothed_probs

# %%
smoothed_probs_1gram = good_turing_smoothing(dict_1gram)

# %% [markdown]
# ## 1-gram smoothed probabilities is stored in smoothed_probs_1gram

# %%
print(smoothed_probs_1gram.get("la"))
# Out:
# [0.00226584]

# %% [markdown]
# ## 2-gram smoothed probabilities is stored in smoothed_probs_1gram

# %%
new_dict = {}

for key, value in dict_2gram.items():
    key_s = ' '.join(key)
    new_dict[key_s] = value

# print(new_dict)
dict_2gram = new_dict

# %%
print(dict_2gram)
# Out:
# {'  ': 17841, '  i': 16695, 'da  ': 15473, '  ve': 14960, '  o': 14498, '  a': 14477, 've  ': 13082, 'de  ': 12868, 'ri  ': 10761, '  bir': 9870, 'ni  ': 9676, 'si  ': 9632, 'nin  ': 9430, '  bu': 9413, 'bir  ': 8575, '  ya': 8250, 'li  ': 8186, 'le  ': 7451, '  e': 6775, 'la ri': 6506, '  ka': 6505, 'le ri': 6344, '  ta': 6238, '  de': 5791, '  ge': 5770, 'ki  ': 5655, 'gi  ': 5582, 'ya  ': 5379, '  da': 5376, '  u': 5368, 'di  ': 5279, 'dan  ': 5261, 'dir  ': 5235, 'lar  ': 5066, 'ne  ': 5061, 'bu  ': 4979, '  sa': 4923, 'na  ': 4787, 'ler  ': 4755, '  ol': 4583, 'rak  ': 4474, 'lan  ': 4461, '  bi': 4250, 'den  ': 4150, ' ': 4060, 'rin  ': 4044, 'o la': 4017, 'la  ': 3940, '  ku': 3707, 'mis tir': 3688, 'la rak': 3593, '  ba': 3544, 'la rin': 3458, 'i le': 3436, 'ra  ': 3383, 'ti  ': 3377, 'tir  ': 3292, 're  ': 3290, '  si': 3207, 'lik  ': 3095, '  do': 3081, '  se': 3011, '  ha': 2991, 'le rin': 2987, 'ma  ': 2981, '  ko': 2955, '  go': 2951, 'mi  ': 2929, '  bas': 2904, '  di': 2829, '  or': 2807, 'ye  ': 2667, 'i cin': 2627, 'ma si': 2607, 'sin da': 2595, '  an': 2496, 'li gi': 2489, 'in  ': 2469, '  ki': 2466, '  su': 2430, '  yi': 2393, '  et': 2384, 'ce  ': 2355, 'te  ': 2349, 'gu  ': 2348, '  al': 2347, '  ye': 2287, 'cin  ': 2274, '  du': 2265, '  son': 2200, 'ci  ': 2191, 'o lan': 2180, '  gi': 2173, 'ca  ': 2165, '  kul': 2162, '  en': 2154, 'mis  ': 2154, 'nu  ': 2138, 'di gi': 2127, '  be': 2127, 'yi  ': 2114, '  ay': 2102, 'a ra': 2043, 'ri ni': 2036, 'se  ': 2013, '  te': 2005, '  is': 1997, '  ce': 1992, '\n ': 1990, 'ri nin': 1933, '  so': 1927, 'lu  ': 1927, 'i  ': 1917, 'ta  ': 1916, '  ma': 1903, 'dir \n': 1893, '  ca': 1887, 'nun  ': 1838, 'bi  ': 1823, 'me  ': 1772, '  gu': 1758, 'en  ': 1751, 'me si': 1740, 'da ki': 1739, 'len  ': 1730, 'ol du': 1712, 'si ni': 1707, 'lir  ': 1698, 'du gu': 1680, '  in': 1666, 'yi lin': 1661, 'son ra': 1613, '  mu': 1607, '  yo': 1603, '  yil': 1603, 'mak ta': 1589, 'kul la': 1583, 'ha  ': 1565, 'du  ': 1504, 'da ha': 1504, 'la ma': 1497, 'lin da': 1493, 'ta dir': 1473, 'sa  ': 1462, '  mo': 1447, 'si nin': 1429, '  tur': 1428, 'ra sin': 1419, 'mek te': 1393, '  top': 1388, '  yer': 1385, 'ta ra': 1380, 'gi bi': 1372, 'nan  ': 1367, 'ri ne': 1363, 'sel  ': 1351, '  kar': 1349, 'bu yuk': 1336, 'i se': 1334, 'rin de': 1320, 'ya pi': 1319, '  on': 1319, '  za': 1318, 'zi  ': 1312, 'ra fin': 1300, 'a  ': 1280, 'de ki': 1273, '  fi': 1256, '  ke': 1252, '  ne': 1249, 'te dir': 1244, 'yan  ': 1239, 'u ze': 1237, '  ci': 1232, 'yuk  ': 1226, 'cak  ': 1221, '  me': 1220, 'fin dan': 1218, 'sin de': 1218, 'tir \n': 1207, 'tik  ': 1207, '  il': 1193, '   ': 1190, 'la ni': 1180, 'su  ': 1180, 'lar da': 1176, 'tur  ': 1172, 'la ra': 1172, '  bo': 1168, 'ger  ': 1147, 'mak  ': 1142, 'rin da': 1139, 'gin  ': 1135, '  la': 1132, 'ol ma': 1121, '  ilk': 1111, 'or ta': 1110, '  ar': 1100, 'bi lir': 1099, 'dun ya': 1098, 'ilk  ': 1094, 'gu nu': 1079, 'ki ye': 1076, 'gi ni': 1074, 'sa yi': 1072, '  dun': 1063, 'si na': 1062, 'ya sa': 1051, 'tan  ': 1049, 'go re': 1039, '  yu': 1035, 'rek  ': 1028, '  ken': 1028, 'mus tur': 1027, '  tu': 1025, 'ul ke': 1022, '  ul': 1008, 'i ki': 1006, '  dev': 1003, 'si ne': 994, '  her': 992, 'tur ki': 988, 'sik  ': 979, '  co': 967, 'ye ni': 963, 'lik le': 959, 'o zel': 958, 'ler de': 956, '  bil': 954, 'man  ': 947, 'ki si': 946, 'bas la': 946, '  var': 942, '  es': 940, 'bi lim': 939, 'ken di': 939, '  dil': 936, 'a na': 933, 'ti gi': 933, '  mi': 930, 'ta ri': 928, '  tek': 914, '  pa': 909, '  par': 902, 'ken  ': 899, 'sal  ': 898, '  bol': 895, '  li': 893, ' de': 889, 'dar  ': 879, 'san  ': 878, 'ka  ': 875, 'kar si': 863, '  kay': 863, 'e  ': 862, '  re': 860, 'o lus': 850, 'ma ya': 848, 'bil gi': 848, 'za man': 845, '  he': 843, '  yap': 836, '  er': 834, 'yer  ': 831, 'bu lun': 829, ' in': 827, '  sis': 827, 'di \n': 820, 'le re': 818, 'her  ': 811, '  uy': 810, 'ko nu': 808, 'ay ri': 807, 'ka dar': 807, 'ca lis': 807, '  ak': 799, 'ren  ': 795 ...

# %%
print(len(dict_2gram))
# Out:
# 33721

# %%
def add_1_smooth(ngram, vocabulary_size):
    # Calculate the total number of bigrams
    total_bigrams = sum(ngram.values())
    
    # Create a new dictionary to store the smoothed bigram probabilities
    smoothed_bigrams = {}
    
    # Iterate over the bigram counts
    for bigram, count in ngram.items():
        # Calculate the add-1 smoothed probability
        prob = (count + 1) / (total_bigrams + vocabulary_size)
        # Store the smoothed probability in the dictionary
        smoothed_bigrams[bigram] = prob
            
    return smoothed_bigrams

# %%
smoothed_probs_2gram = add_1_smooth(dict_2gram, len(dict_2gram))

# %%
print(smoothed_probs_2gram['top lu'])
# Out:
# 0.0001601774273040907

# %%
new_dict = {}

for key, value in dict_3gram.items():
    key_s = ' '.join(key)
    new_dict[key_s] = value

# print(new_dict)
dict_3gram = new_dict

# %%
print(dict_3gram)
# Out:
# {'    ': 179, '  ve  ': 12922, '  bir  ': 8284, '  bu  ': 4617, '  o la': 3999, 'la ri  ': 3960, 'le ri  ': 3724, 'la rak  ': 3590, 'o la rak': 3320, '   ': 1076, '  i le': 3192, 'i le  ': 2949, 'mis tir  ': 2645, '  i cin': 2625, '  da  ': 2391, '  o lan': 2175, 'sin da  ': 2152, 'o lan  ': 2118, 'i cin  ': 2063, '  de  ': 2046, '  a ra': 2034, 'ri ni  ': 2021, 'la rin  ': 1979, 'ri nin  ': 1928, '   yi': 15, 'le rin  ': 1755, 'di gi  ': 1691, '  en  ': 1690, '  ol du': 1687, 'da ki  ': 1669, '  son ra': 1609, '  kul la': 1559, '  yi lin': 1549, 'si ni  ': 1542, 'ma si  ': 1530, 'li gi  ': 1480, 'lin da  ': 1452, 'da ha  ': 1450, 'mak ta dir': 1437, '  da ha': 1427, 'si nin  ': 1425, 'yi lin da': 1410, 'ra sin da': 1395, '  gi bi': 1368, '  ta ra': 1352, 'ri ne  ': 1352, 'gi bi  ': 1341, 'i se  ': 1326, '  i se': 1324, '  bu yuk': 1314, '  ya pi': 1267, 'de ki  ': 1260, 'ta ra fin': 1247, '  u ze': 1234, 'son ra  ': 1228, 'mek te dir': 1226, 'fin dan  ': 1217, 'ra fin dan': 1213, 'bu yuk  ': 1205, '\n   ': 1201, 'du gu  ': 1184, 'rin de  ': 1141, '  ol ma': 1119, 'a ra sin': 1111, '  ilk  ': 1092, 'ol du gu': 1086, '  or ta': 1071, 'lar da  ': 1070, 'gi ni  ': 1066, 'sin de  ': 1061, '  dun ya': 1060, '  go re': 1033, 'la rin da': 1030, 'me si  ': 1030, 'rin da  ': 1019, 'si   i': 1005, 'si na  ': 1002, '  sa yi': 1000, 'mis tir \n': 989, 'tur ki ye': 987, '  ul ke': 982, 'ta dir  ': 980, '  i ki': 975, 've   ': 2, 'da   ': 2, '  bas la': 944, 'le ri ni': 938, 'la ra  ': 938, '  o zel': 933, '  ye ni': 931, '  ken di': 923, 'si ne  ': 896, 'ri   i': 884, '  a na': 873, 'ler de  ': 870, '  tur ki': 858, 'kul la ni': 850, '  bi lim': 844, '  kar si': 843, '  o lus': 838, 'la ri ni': 833, 'i ki  ': 829, ' de  ': 826, '  za man': 822, '  bu lun': 821, '  ta ri': 817, 'le re  ': 815, 'la ri nin': 813, '  ka dar': 806, '  ca lis': 804, 'li   bir': 803, '  yer  ': 803, 'de   ': 4, '  ko nu': 795, 'te dir  ': 794, '  ya sa': 792, ' in  ': 785, 'ka dar  ': 783, 'le ri nin': 781, '  i  ': 772, 'go re  ': 770, 'ti gi  ': 765, '  si ra': 764, '  bil gi': 761, '  bol ge': 760, '  ay ri': 757, '  ge lis': 746, '  o nem': 745, 'ri na  ': 743, '  her  ': 741, '  e di': 740, '  a lan': 736, 'ri   a': 735, 'mus tur  ': 730, 'ma ya  ': 721, 'di ger  ': 698, '  di ger': 696, 'da   i': 694, 'le rin de': 692, '   a': 70, 'bi lir  ': 682, '  et ki': 681, '  bu lu': 681, 'di   ve': 679, 'li   o': 679, 'o nem li': 678, 've ya  ': 675, 'gu nu  ': 675, '  ve ya': 674, '  ku ru': 669, 'la ri na': 669, '   ta': 24, '  ya zi': 661, '  e dil': 660, '  ge nel': 659, 'an cak  ': 658, '  o lu': 651, 'le ri ne': 649, 'dir   bu': 648, '  an cak': 640, 'ye ni  ': 637, 'nem li  ': 636, 'rin den  ': 633, '   ve': 632, '  be lir': 631, '  bi li': 629, 'av ru pa': 628, '  sa hip': 624, 'da   bu': 617, '  bi ri': 614, 'ri   ve': 613, '  bir lik': 613, 'si   ve': 610, 'de   bu': 609, '  a la': 607, '  an la': 605, 'si   o': 603, 'o zel lik': 599, 'ya   da': 598, ' da  ': 598, '  ya  ': 598, 'ca lis ma': 597, 'di   ': 8, 'lik le  ': 592, '   i': 143, '  ki si': 589, '  av ru': 588, 'ay ni  ': 587, '  on ce': 581, '  ay ni': 581, 'ki ye  ': 576, 'lar dan  ': 564, '  ol mus': 562, 'mi nin  ': 562, 'la ma  ': 557, 'lik te  ': 552, '  do ne': 548, 'mi ni  ': 545, '  a di': 545, 'da   ya': 542, 'ler den  ': 540, '  su re': 539, ' nin  ': 537, '  ba zi': 533, '  ve ri': 532, '   o': 20, 'i cin de': 529, '  fark li': 527, '  do nem': 526, 'cin de  ': 525, '   de': 159, 'zel lik le': 524, '  yo ne': 523, 'bir lik te': 523, '  in san': 522, ' te  ': 522, 'le rin den': 517, '   yil': 10, 'si   ': 32, '  il gi': 509, 'u ze rin': 509, '  ger cek': 503, 'ma la ri': 503, '  i ce': 502, 'ri   o': 501, 'dun ya  ': 498, '  ': 496, 'ta ya  ': 494, 'ri ca  ': 493, '  so nu': 490, '  sis te': 489, '  se kil': 488, 'ay ri ca': 486, '  a cik': 485, ' \n ': 484, '  gu nu': 484, 'de   ya': 483, 'ra si  ': 483, '  yil  ': 480, '  es ki': 480, '  et ti': 475, 'ya pi lan': 472, 'or ta ya': 471,  ...

# %%
print(len(dict_3gram))
# Out:
# 166410

# %%
smoothed_probs_3gram = add_1_smooth(dict_3gram, len(dict_3gram))

# %%
print(smoothed_probs_3gram['  ve  '])
# Out:
# 0.007856719887842785

# %% [markdown]
# ## All smoothings are done now. Stored in `smoothed_probs_1gra` , `smoothed_probs_2gram` and `smoothed_probs_3gram`.

# %% [markdown]
# `Note that, good-turing smoothing not efficient for bigram and threegrams. I used add-1(Laplace) smoothing for them.`

# %%
print(smoothed_probs_1gram["la"])
# Out:
# [0.00226584]

# %%
print(smoothed_probs_2gram['mek te'])
# Out:
# 0.0009039973022749086

# %%
print(smoothed_probs_3gram['o la rak'])
# Out:
# 0.002019048730753377

# %% [markdown]
# # Calculating perplexity using unigram

# %%
import math
def calculate_perplexity(test_words, training_set_probs, unknown_word_prob=0):
    # Initialize variables
    product = 1
    n_words = len(test_words)
  
    # Calculate probability for each test word
    for word in test_words:
        if word in training_set_probs:
        # Calculate probability using training set probabilities
            prob = training_set_probs[word]
        else:
        # Assign probability of unknown word
            prob = unknown_word_prob
        # Update product
        product *= prob
  
    # Calculate perplexity
    perplexity = math.exp(1/product)
  
    return perplexity
